# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import requests
import urllib.request
from pandas.io.json import json_normalize

# %%
# Import coins file as DataFrame
coins_df = pd.read_csv("../resources/coingecko_symbols.csv")

# %%
# Add columns for sentiment
# Note that we used "" to specify initial entry.
coins_df["category"] = ""
coins_df["sector"] = ""
coins_df
# Out:
#     symbol            id category sector
# 0      btc       bitcoin
# 1      eth      ethereum
# 2     usdt        tether
# 3      bnb   binancecoin
# 4      ada       cardano
# ..     ...           ...      ...    ...
# 245   wnxm   wrapped-nxm
# 246    tlm  alien-worlds
# 247    loc     lockchain
# 248   inst     instadapp
# 249   keep  keep-network
#
# [250 rows x 4 columns]

# %%
coins_df = coins_df.iloc[60:120]
coins_df
# Out:
#      symbol                     id category sector
# 60       ht            huobi-token
# 61    sushi                  sushi
# 62     hbar       hedera-hashgraph
# 63     tusd               true-usd
# 64    waves                  waves
# 65      chz                 chiliz
# 66    steth           staked-ether
# 67     hbtc              huobi-btc
# 68     dash                   dash
# 69      stx             blockstack
# 70      zec                  zcash
# 71      enj              enjincoin
# 72      yfi          yearn-finance
# 73      xdc        xdce-crowd-sale
# 74      hnt                 helium
# 75      xem                    nem
# 76      tel                telcoin
# 77      hot              holotoken
# 78      qnt          quant-network
# 79      axs          axie-infinity
# 80      kcs          kucoin-shares
# 81     mana           decentraland
# 82      pax         paxos-standard
# 83     nexo                   nexo
# 84      zil                zilliqa
# ...

# %%
base_url = "https://data.messari.io/api/v2/assets/"
# https://data.messari.io/api/v2/assets/{assetKey}/profile
base_url
# Out:
# 'https://data.messari.io/api/v2/assets/'

# %%
header = {"x-messari-api-key": "291b4bba-a9be-4e80-a3d3-8131b1208c8e"}
header
# Out:
# {'x-messari-api-key': '291b4bba-a9be-4e80-a3d3-8131b1208c8e'}

# %%
symbol = "btc"# Use the search term: "Coin" and our symbol
url = f"{base_url}{symbol}/profile"

# %%
url
# Out:
# 'https://data.messari.io/api/v2/assets/btc/profile'

# %%
headers
# Out:
# {'x-messari-api-key': '291b4bba-a9be-4e80-a3d3-8131b1208c8e'}

# %%
response = requests.get('https://data.messari.io/api/v2/assets/eth/profile', headers).json()
response
# Out:
# {'status': {'elapsed': 5, 'timestamp': '2021-07-14T16:36:13.585121136Z'},
#  'data': {'id': '21c795f5-1bfd-40c3-858e-e9d7e820c6d0',
#   'symbol': 'ETH',
#   'name': 'Ethereum',
#   'slug': 'ethereum',
#   'contract_addresses': [{'platform': 'binance-smart-chain',
#     'contract_address': '0x2170ed0880ac9a755fd29b2688956bd959f933f8'},
#    {'platform': 'huobi-token',
#     'contract_address': '0x64ff637fb478863b7468bc97d30a5bf3a428a1fd'},
#    {'platform': 'tomochain',
#     'contract_address': '0x2eaa73bd0db20c64f53febea7b5f5e5bccc7fb8b'}],
#   '_internal_temp_agora_id': '263d8b01-5a96-41f0-85d5-09687bbbf7ca',
#   'profile': {'general': {'overview': {'is_verified': False,
#      'tagline': 'A decentralized computing platform',
#      'category': 'Infrastructure',
#      'sector': 'Smart Contract Platforms',
#      'tags': None,
# ...

# %%
response = requests.get(url).json()
# , headers=header

# %%
    # make request and print url
    response = requests.get(url).json()

# %%
# Use the coins_df file to select symbol from sentiment data
for index, row in coins_df.iterrows():
    # get coin symbol
    symbol = row["symbol"]

    # Use the search term: "Coin" and our symbol
    url = f"{base_url}{symbol}/profile"

    # make request and print url
    response = requests.get(url), heaer.json()
    

#     # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        coins_df.loc[index,"category"] = response["data"]["profile"]["general"]["overview"]["category"]
        coins_df.loc[index,"sector"] = response["data"]["profile"]["general"]["overview"]["sector"]
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# /Users/bobc/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/bobc/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# Missing field/result... skipping.
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-63-52847f6c58fc> in <module>
#       8
# ...

# %%
coins_df

# %%
coins_df.to_csv("../resources/categories75.csv", index=True)

# %%
# Create csv file with messari data
coins_df.to_csv("../resources/categoriesm.csv", mode = 'a', header=False, index=True)
