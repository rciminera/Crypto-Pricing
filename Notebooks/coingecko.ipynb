# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import tensorflow as tf
import glob
import numpy as np
import yfinance as yf
import plotly.graph_objs as go
import json
import re

# %%
df = pd.read_json('coingecko.json')
df = df.drop(['roi'], axis=1)
df
# Out:
#              id symbol          name  \
# 0       bitcoin    btc       Bitcoin
# 1      ethereum    eth      Ethereum
# 2        tether   usdt        Tether
# 3   binancecoin    bnb  Binance Coin
# 4       cardano    ada       Cardano
# ..          ...    ...           ...
# 95         nano   nano          Nano
# 96         qtum   qtum          Qtum
# 97      harmony    one       Harmony
# 98     livepeer    lpt      Livepeer
# 99         ankr   ankr          Ankr
#
#                                                 image  current_price  \
# 0   https://assets.coingecko.com/coins/images/1/la...   32797.000000
# 1   https://assets.coingecko.com/coins/images/279/...    1913.880000
# 2   https://assets.coingecko.com/coins/images/325/...       1.000000
# 3   https://assets.coingecko.com/coins/images/825/...     287.220000
# 4   https://assets.coingecko.com/coins/images/975/...       1.260000
# ..                                                ...            ...
# 95  https://assets.coingecko.com/coins/images/756/...       4.430000
# 96  https://assets.coingecko.com/coins/images/684/...       5.700000
# 97  https://assets.coingecko.com/coins/images/4344...       0.057211
# 98  https://assets.coingecko.com/coins/images/7137...      23.480000
# 99  https://assets.coingecko.com/coins/images/4324...       0.076713
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0   613445605654                1             6.873702e+11   34555888553
# 1   222390190706                2                      NaN   23908726300
# 2    63022120901                3                      NaN   68324287457
# 3    44366122128                4             4.895967e+10    2475300335
# 4    40457686977                5             5.677583e+10    5261050655
# ..           ...              ...                      ...           ...
# 95     590740494               96                      NaN      29640204
# 96     589271888               97                      NaN     281314240
# 97     578289380               98                      NaN      39586875
# 98     560000174               99             5.600002e+08      75855624
# 99     532255304              100                      NaN     264707311
#
#         high_24h  ...  total_supply    max_supply           ath  \
# 0   34877.000000  ...  2.100000e+07  2.100000e+07  64805.000000
# 1    2043.520000  ...           NaN           NaN   4356.990000
# 2       1.010000  ...  6.282735e+10           NaN      1.320000
# 3     308.030000  ...  1.705337e+08  1.705337e+08    686.310000
# 4       1.300000  ...  4.500000e+10  4.500000e+10      2.450000
# ..           ...  ...           ...           ...           ...
# 95      4.890000  ...  1.332483e+08           NaN     33.690000
# 96      6.070000  ...  1.078224e+08           NaN    100.220000
# 97      0.063323  ...           NaN           NaN      0.222092
# 98     29.050000  ...  2.379152e+07  2.379152e+07     45.440000
# 99      0.080915  ...  1.000000e+10           NaN      0.213513
#
#     ath_change_percentage                  ath_date        atl  \
# 0               -49.56718  2021-04-14T11:54:46.763Z  67.810000
# 1               -56.23540  2021-05-12T14:41:48.623Z   0.432979
# 2               -24.18535  2018-07-24T00:00:00.000Z   0.572521
# 3               -58.36577  2021-05-10T07:24:17.097Z   0.039818
# 4               -48.81758  2021-05-16T07:44:28.033Z   0.019253
# ..                    ...                       ...        ...
# 95              -86.90950  2018-01-02T00:00:00.000Z   0.026179
# 96              -94.38772  2018-01-06T00:00:00.000Z   0.783142
# 97              -74.49687  2021-03-29T08:19:36.363Z   0.001274
# 98              -48.20506  2021-05-11T00:24:44.019Z   0.354051
# 99              -64.36875  2021-04-16T19:44:04.474Z   0.000707
#
#     atl_change_percentage                  atl_date              last_updated  \
# 0             48098.39236  2013-07-06T00:00:00.000Z  2021-06-24T03:32:13.383Z
# 1            440295.54264  2015-10-20T00:00:00.000Z  2021-06-24T03:32:18.562Z
# 2                75.20756  2015-03-02T00:00:00.000Z  2021-06-24T03:05:22.478Z
# 3            717516.76117  2017-10-19T00:00:00.000Z  2021-06-24T03:32:06.794Z
# 4              6401.17847  2020-03-13T02:22:55.044Z  2021-06-24T03:31:57.382Z
# ..                    ...                       ...                       ...
# 95            16748.13414  2017-07-16T00:00:00.000Z  2021-06-24T03:31:53.171Z
# 96              618.24131  2020-03-13T02:22:57.149Z  2021-06-24T03:32:06.516Z
# 97             4347.44012  2020-03-13T02:24:14.005Z  2021-06-24T03:31:38.271Z
# 98             6548.14505  2019-10-26T22:59:09.500Z  2021-06-24T03:31:53.967Z
# 99            10656.30112  2020-03-13T02:24:03.563Z  2021-06-24T03:31:33.090Z
#
#     price_change_percentage_1y_in_currency
# 0                               240.754724
# 1                               687.349174
# 2                                 0.339049
# 3                              1653.894404
# 4                              1424.420085
# ..                                     ...
# 95                              298.117142
# 96                              218.038207
# 97                             1070.261032
# 98                              736.849222
# 99                             2422.493588
#
# [100 rows x 26 columns]

# %%
df.to_csv(r'Resources\coin.csv')
