# %%
#  Import our dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import requests
import urllib.request
from pandas.io.json import json_normalize

# %%
# Get 250 coins with 30, 200day, and 1 Year pricing changes from Coin Gecko
# url= "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=250&page=1&sparkline=false&price_change_percentage=30d%2C200d%2C1y"
url= "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=250&page=1&sparkline=false&price_change_percentage=30d%2C200d%2C1y"
df = pd.read_json(url)
df
# Out:
#                id symbol          name  \
# 0         bitcoin    btc       Bitcoin
# 1        ethereum    eth      Ethereum
# 2          tether   usdt        Tether
# 3     binancecoin    bnb  Binance Coin
# 4         cardano    ada       Cardano
# ..            ...    ...           ...
# 245   wrapped-nxm   wnxm   Wrapped NXM
# 246  alien-worlds    tlm  Alien Worlds
# 247     lockchain    loc      LockTrip
# 248     instadapp   inst     Instadapp
# 249  keep-network   keep  Keep Network
#
#                                                  image  current_price  \
# 0    https://assets.coingecko.com/coins/images/1/la...   33944.000000
# 1    https://assets.coingecko.com/coins/images/279/...    2143.050000
# 2    https://assets.coingecko.com/coins/images/325/...       1.000000
# 3    https://assets.coingecko.com/coins/images/825/...     316.100000
# 4    https://assets.coingecko.com/coins/images/975/...       1.350000
# ...

# %%
count_df = df[df["price_change_percentage_1y_in_currency"] >= 0].count()
count_df
# Out:
# id                                          161
# symbol                                      161
# name                                        161
# image                                       161
# current_price                               161
# market_cap                                  161
# market_cap_rank                             161
# fully_diluted_valuation                      57
# total_volume                                161
# high_24h                                    161
# low_24h                                     161
# price_change_24h                            161
# price_change_percentage_24h                 161
# market_cap_change_24h                       161
# market_cap_change_percentage_24h            161
# circulating_supply                          161
# total_supply                                146
# max_supply                                   57
# ath                                         161
# ath_change_percentage                       161
# ...

# %%
count_df = df[df["price_change_percentage_200d_in_currency"] >= 0].count()
count_df
# Out:
# id                                          206
# symbol                                      206
# name                                        206
# image                                       206
# current_price                               206
# market_cap                                  206
# market_cap_rank                             206
# fully_diluted_valuation                      94
# total_volume                                206
# high_24h                                    206
# low_24h                                     206
# price_change_24h                            206
# price_change_percentage_24h                 206
# market_cap_change_24h                       206
# market_cap_change_percentage_24h            206
# circulating_supply                          206
# total_supply                                190
# max_supply                                   94
# ath                                         206
# ath_change_percentage                       206
# ...

# %%
count_df = df[df["price_change_percentage_30d_in_currency"] >= 0].count()
count_df
# Out:
# id                                          48
# symbol                                      48
# name                                        48
# image                                       48
# current_price                               48
# market_cap                                  48
# market_cap_rank                             48
# fully_diluted_valuation                     17
# total_volume                                48
# high_24h                                    48
# low_24h                                     48
# price_change_24h                            48
# price_change_percentage_24h                 48
# market_cap_change_24h                       48
# market_cap_change_percentage_24h            48
# circulating_supply                          48
# total_supply                                48
# max_supply                                  17
# ath                                         48
# ath_change_percentage                       48
# ...

# %%
# Create a dataframe with symbol and coin id to pass to lunar crush extract

df_symbol = df[["symbol","id"]]
df_symbol
# Out:
#     symbol            id
# 0      btc       bitcoin
# 1      eth      ethereum
# 2     usdt        tether
# 3      bnb   binancecoin
# 4      ada       cardano
# ..     ...           ...
# 245   wnxm   wrapped-nxm
# 246    tlm  alien-worlds
# 247    loc     lockchain
# 248   inst     instadapp
# 249   keep  keep-network
#
# [250 rows x 2 columns]

# %%
# Create csv to pass to LunarCrush
df_symbol.to_csv("../resources/coingecko_symbols.csv", index=False)

# %%
# Create csv to pass coingecko_coindata_extract.csv to Database Load
df.to_csv("../resources/crypto_coindata.csv", index=False)

# %%
# Get 250 coins with 30, 200day, and 1 Year pricing changes from Coin Gecko
# url= "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=250&page=1&sparkline=false&price_change_percentage=30d%2C200d%2C1y"
# url= "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=250&page=1&sparkline=false&price_change_percentage=30d%2C200d%2C1y"
url= "https://api.coingecko.com/api/v3/coins/btc?tickers=false&market_data=true"
